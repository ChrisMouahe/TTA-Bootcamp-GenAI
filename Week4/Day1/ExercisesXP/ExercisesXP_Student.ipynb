# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# **Enoncé du problème :**
# L'objectif du projet est de pouvoir prédire si un client à qui la banque fait un prêt, fera un défaut de paiement ou non; la variable cible est alors default_payment.
#
# **Type de données à collecter : **
# * Informations personnelles : Certaines caractéristiques démographiques (situation matrimoniale, nombre d'enfants...) peuvent être associés à des comportements financiers différents.
# * Situation professionnelle : Une personne ayant un emploi stable présente généralement un risque plus faible.
# * Revenus : Un revenu élevé augmente généralement la capacité de remboursement.
# * Historique de crédit : Le comportement passé est souvent un bon indicateur du comportement futur.
# * Informations sur le prêt : Des prêts importants ou de longue durée peuvent présenter davantage de risques.
# * Endettement actuel : Une personne déjà fortement endettée aura plus de difficultés à rembourser un nouveau prêt.
#
# **Sources possibles des données : **
#
# * Base de données interne de la banque : Les données internes peuvent être obtenues directement à partir des systèmes de gestion de la banque. Elles sont extraites via des requêtes sur les bases de données puis intégrées dans une plateforme analytique où elles sont nettoyées et préparées pour la modélisation.
# * Agences d'évaluation du crédit : Les informations provenant des agences d'évaluation du crédit peuvent être obtenues grâce à des accords de partage de données. Elles sont généralement intégrées au système bancaire via des API sécurisées permettant de récupérer automatiquement les scores de crédit et les historiques de paiement.
# * Formulaires de demande de prêt : Les données déclaratives des clients sont recueillies lors de la soumission des demandes de prêt. Elles sont enregistrées directement dans le système d'information de la banque et peuvent être intégrées automatiquement au jeu de données utilisé pour l'entraînement du modèle.
# * Systèmes bancaires transactionnels : Les données transactionnelles sont collectées à partir des systèmes bancaires opérationnels. Elles sont intégrées dans l'environnement analytique grâce à des processus ETL qui extraient, transforment et chargent les informations pertinentes pour l'analyse du risque de crédit.
# * Documents justificatifs fournis par les clients : Les justificatifs transmis par les clients peuvent être collectés sous forme numérique. Les informations essentielles sont extraites à l'aide d'outils d'OCR puis intégrées dans la base de données utilisée pour l'évaluation du risque.
#
# **Risques et contraintes : **
# La prédiction des défauts de paiement présente plusieurs contraintes. Les données financières et personnelles des clients doivent être protégées conformément aux réglementations sur la confidentialité. La qualité des données est également essentielle, car des informations incomplètes ou erronées peuvent affecter les performances du modèle. De plus, les données historiques peuvent contenir des biais susceptibles d’influencer les prédictions. Enfin, une bonne gouvernance des données est nécessaire pour garantir leur sécurité, leur cohérence et leur utilisation responsable.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]
df = pd.DataFrame(columns=example_columns)

# Please replace this list with the actual columns that you select.
selected_features = ['credit_score', 'debt_to_income', 'annual_income', 'num_delinquencies', 'loan_amount', 'employment_length'
                ]
print("You will now justify the selected features in complete sentences below.")
# Out:
# You will now justify the selected features in complete sentences below.

# %% [markdown]
# **Justifications : ** * credit_score : Un faible score est généralement associé à un risque plus élevé.
# * debt_to_income :	Mesure la part des revenus déjà utilisée pour rembourser des dettes. Un ratio élevé indique un risque accru.
# * annual_income :	Permet d'évaluer la capacité financière du client à rembourser son prêt.
# * num_delinquencies :	Les retards de paiement passés sont souvent prédictifs des difficultés futures.
# * loan_amount :	Un montant de prêt élevé peut augmenter le risque de non-remboursement.
# * employment_length :
# Une situation professionnelle stable est généralement associée à un risque plus faible.
#
# **Variables exclues : **
# * age	: L'âge peut influencer la stabilité financière, mais il est souvent moins prédictif que le revenu, le score de crédit ou l'historique de paiement.
# * interest_rate :	Le taux est souvent fixé en fonction du risque du client. Il peut donc être une conséquence du risque plutôt qu'une cause directe.
# * num_open_accounts :	Le nombre de comptes ouverts n'est pas forcément problématique. Une personne peut avoir plusieurs comptes tout en gérant parfaitement ses finances.
# * total_utilization :	Variable intéressante, mais elle est partiellement liée à l'endettement déjà mesuré par le ratio dette/revenu (debt_to_income).
# * home_ownership :	Être propriétaire peut réduire le risque, mais ce facteur est généralement moins déterminant que les revenus ou l'historique de crédit.
# * purpose :	L'objet du prêt peut avoir un impact, mais son pouvoir prédictif est souvent inférieur aux variables financières.
# * term :	La durée du prêt influence le risque, mais elle n'est pas aussi informative que la capacité réelle de remboursement du client.
# * application_type :	Le type de demande (individuelle ou conjointe) peut jouer un rôle, mais son effet est généralement secondaire.
# * state :	Peut refléter certaines conditions économiques locales, mais son impact est souvent faible et variable selon les régions.
# * zip_code :	Peut apporter une information géographique, mais risque d'introduire des biais et des problèmes d'équité dans les décisions.
#
# Les variables catégorielles, telles que home_ownership, purpose ou application_type, seront converties en variables numériques à l’aide de techniques d’encodage comme le One-Hot Encoding afin qu’elles puissent être utilisées par les algorithmes de Machine Learning. Les valeurs manquantes seront imputées à l’aide de méthodes adaptées, par exemple en remplaçant les données numériques manquantes par la médiane et les données catégorielles par la modalité la plus fréquente, afin de préserver la qualité du jeu de données.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0
#
# Confusion matrix:
#  [[6 0]
#  [0 4]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %% [markdown]
# Pour prédire les défauts de paiement, je choisirais la Régression Logistique comme modèle de base pour son interprétabilité et le Random Forest pour sa capacité à capturer des relations complexes entre les variables. Les données seraient divisées en ensembles d'entraînement et de test selon une proportion de 80/20, puis évaluées à l'aide d'une validation croisée stratifiée à 5 plis. Les performances seraient mesurées à l'aide de la précision, du rappel, du score F1 et de l'AUC-ROC. Le seuil de décision serait ajusté en fonction du compromis souhaité entre détection des défauts et limitation des faux positifs. Pour gérer le déséquilibre des classes, j'utiliserais la stratification, la pondération des classes ou des techniques de rééchantillonnage telles que SMOTE. Enfin, les hyperparamètres seraient optimisés par Grid Search ou Random Search avec validation croisée, tout en évitant les fuites de données grâce à une séparation stricte entre les données d'entraînement et de test.

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# La prédiction des cours boursiers est un problème d'apprentissage supervisé, car le modèle est entraîné sur des données historiques contenant des valeurs connues. Les données d'entrée comprennent les cours passés, les volumes de transactions et d'autres indicateurs financiers. La sortie est le cours futur de l'action ou son évolution. L'objectif d'apprentissage est de minimiser l'écart entre les prédictions et les valeurs réelles.
#
# L'organisation d'une bibliothèque est un problème d'apprentissage non supervisé, car il s'agit de regrouper les livres selon leurs similitudes sans disposer d'étiquettes prédéfinies. Les données d'entrée peuvent inclure les titres, les résumés et les mots-clés des ouvrages. La sortie consiste en groupes de livres similaires. L'objectif est de découvrir automatiquement des structures ou des catégories naturelles dans les données.
#
# La programmation d'un robot pour naviguer dans un labyrinthe correspond à l'apprentissage par renforcement, car le robot apprend en interagissant avec son environnement. Les données d'entrée représentent son état actuel et les informations disponibles sur le labyrinthe. La sortie est l'action à effectuer, comme avancer ou changer de direction. L'objectif d'apprentissage est de maximiser les récompenses obtenues afin de trouver le chemin le plus court vers la sortie.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("Please explain in complete sentences when you would use the elbow method and how you would interpret it.")
# Out:
# Silhouette score (higher is better): 0.848
# Please explain in complete sentences when you would use the elbow method and how you would interpret it.

# %% [markdown]
# ### Modèle d'apprentissage supervisé (Classification)
#
# Pour un modèle supervisé de classification, comme la prédiction des défauts de paiement, je diviserais les données en ensembles d'entraînement et de test afin d'évaluer les performances sur des données jamais vues par le modèle. J'utiliserais également une validation croisée afin d'obtenir une estimation plus fiable des performances et de réduire le risque de surapprentissage. Les indicateurs communiqués seraient l'exactitude (*accuracy*), la précision (*precision*), le rappel (*recall*) et le score F1, qui permettent d'évaluer différents aspects de la qualité des prédictions. J'utiliserais aussi la courbe ROC et l'AUC-ROC pour mesurer la capacité du modèle à distinguer les différentes classes. Le principal défi de l'évaluation des modèles supervisés est de choisir des métriques adaptées lorsque les classes sont déséquilibrées, car l'exactitude seule peut être trompeuse.
#
# ---
#
# ### Modèle d'apprentissage non supervisé (Clustering)
#
# Pour un modèle de clustering, comme le regroupement de clients ou de livres selon leurs similitudes, l'évaluation repose principalement sur la qualité des groupes formés. J'utiliserais le score de silhouette afin de mesurer la cohésion des observations au sein d'un même cluster et leur séparation par rapport aux autres clusters. La méthode du coude (*Elbow Method*) serait également utilisée pour déterminer le nombre optimal de clusters en analysant la variation de l'inertie. D'autres métriques de validation interne, comme l'indice de Davies-Bouldin ou l'indice de Calinski-Harabasz, pourraient compléter l'analyse. Des graphiques de diagnostic, tels que le graphique du coude ou des visualisations des clusters, permettraient de mieux interpréter les résultats. Le principal défi de l'évaluation des modèles non supervisés est l'absence de véritables étiquettes de référence pour confirmer la qualité des regroupements obtenus.
#
# ---
#
# ### Modèle d'apprentissage par renforcement
#
# Pour un modèle d'apprentissage par renforcement, comme un robot apprenant à naviguer dans un labyrinthe, je mesurerais la performance à l'aide de la récompense cumulative obtenue au cours des épisodes d'entraînement. Une augmentation progressive de cette récompense indiquerait que l'agent améliore sa stratégie. J'évaluerais également la convergence du modèle en observant si les performances se stabilisent après un certain nombre d'itérations. L'équilibre entre exploration et exploitation serait suivi afin de s'assurer que l'agent continue à découvrir de nouvelles stratégies tout en exploitant les meilleures actions déjà apprises. Des courbes représentant l'évolution des récompenses au fil du temps permettraient de visualiser les progrès réalisés. Le principal défi de l'évaluation en apprentissage par renforcement est que les performances peuvent varier fortement selon l'environnement et nécessiter un grand nombre d'interactions avant de pouvoir être mesurées de manière fiable.
